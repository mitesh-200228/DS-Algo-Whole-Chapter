# %%
dict1 = {
    "Name":["Mitesh","Ankit","Nehanshu","Viral"],
    "Marks":[50,51,52,53],
    "Subject":["Maths","English","Hindi","Gujarati"],
}

# %%
x = pd.DataFrame(dict1)

# %%
x
# Out:
#        Name  Marks   Subject
# 0    Mitesh     50     Maths
# 1     Ankit     51   English
# 2  Nehanshu     52     Hindi
# 3     Viral     53  Gujarati

# %%
x.to_csv("data.csv",index=False)

# %%
mitesh = pd.read_csv('data.csv')

# %%
mitesh
# Out:
#        Name  Marks   Subject
# 0    Mitesh     50     Maths
# 1     Ankit     51   English
# 2  Nehanshu     52     Hindi
# 3     Viral     53  Gujarati

# %%
op = x.describe()
op
# Out:
#            Marks
# count   4.000000
# mean   51.500000
# std     1.290994
# min    50.000000
# 25%    50.750000
# 50%    51.500000
# 75%    52.250000
# max    53.000000

# %%
x['Marks'][0] = 10
# Out:
# C:\Users\Mitesh\AppData\Local\Temp/ipykernel_17036/2308498176.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Marks'][0] = 10

# %%
x
# Out:
#        Name  Marks   Subject
# 0    Mitesh     10     Maths
# 1     Ankit     51   English
# 2  Nehanshu     52     Hindi
# 3     Viral     53  Gujarati

# %%
x.to_csv("data.csv")

# %%
x.index = ['1','2','3','4']

# %%
x
# Out:
#        Name  Marks   Subject
# 1    Mitesh     10     Maths
# 2     Ankit     51   English
# 3  Nehanshu     52     Hindi
# 4     Viral     53  Gujarati

# %%
y = pd.Series(np.random.rand(50))

# %%
y
# Out:
# 0     0.293338
# 1     0.487475
# 2     0.111271
# 3     0.631393
# 4     0.839751
# 5     0.211021
# 6     0.322424
# 7     0.884041
# 8     0.801636
# 9     0.108051
# 10    0.022988
# 11    0.030261
# 12    0.262361
# 13    0.472059
# 14    0.539934
# 15    0.531697
# 16    0.143955
# 17    0.861352
# 18    0.179703
# 19    0.186050
# 20    0.309824
# 21    0.943670
# 22    0.406712
# 23    0.936672
# 24    0.168754
# 25    0.429145
# 26    0.529603
# 27    0.943357
# 28    0.080302
# 29    0.263195
# 30    0.950358
# 31    0.425154
# 32    0.202700
# 33    0.506313
# 34    0.342542
# 35    0.391237
# 36    0.051426
# 37    0.482795
# 38    0.307829
# 39    0.448144
# 40    0.547812
# 41    0.140144
# 42    0.599568
# 43    0.038075
# 44    0.468575
# 45    0.707917
# 46    0.418498
# 47    0.437880
# 48    0.304412
# 49    0.317171
# dtype: float64

# %%
newdf = pd.DataFrame(np.random.rand(440,4), index=np.arange(440))

# %%
newdf.head(40)
# Out:
#            0         1         2         3
# 0   0.331077  0.975898  0.889849  0.859923
# 1   0.877626  0.990214  0.223008  0.222125
# 2   0.339702  0.391582  0.127354  0.186248
# 3   0.037742  0.380315  0.162264  0.498827
# 4   0.655820  0.899829  0.742747  0.135883
# 5   0.498695  0.883546  0.626131  0.024243
# 6   0.665918  0.885154  0.174214  0.120631
# 438  0.429560  0.865090  0.903554  0.655797
# 439  0.215604  0.163804  0.803735  0.343675
#
# [440 rows x 4 columns]

# %%
newdf.head(40)
# Out:
#            0         1         2         3
# 0   0.193673  0.905072  0.125517  0.313596
# 1   0.005045  0.471557  0.084760  0.001724
# 2   0.066127  0.640431  0.249290  0.706031
# 3   0.911217  0.294054  0.016739  0.998522
# 4   0.797130  0.690922  0.868651  0.518091
# 5   0.943599  0.273909  0.383969  0.852607
# 6   0.512860  0.594444  0.086918  0.685872
# 7   0.044101  0.309941  0.680460  0.731509
# 8   0.020814  0.514056  0.650472  0.995066
# 9   0.385256  0.443689  0.517156  0.556655
# 10  0.519625  0.610908  0.607716  0.393242
# 11  0.764278  0.279594  0.740195  0.371274
# 12  0.756660  0.990370  0.192267  0.950760
# 13  0.742509  0.994540  0.585510  0.827425
# 14  0.467024  0.173257  0.978018  0.597953
# 15  0.096145  0.380177  0.499149  0.848187
# 16  0.384515  0.624744  0.042456  0.338519
# 17  0.916490  0.268166  0.667313  0.584325
# 18  0.888910  0.763526  0.555084  0.863722
# 19  0.856201  0.763432  0.271122  0.896314
# 20  0.471441  0.689726  0.024983  0.886841
# ...

# %%
newdf.to_numpy()
# Out:
# array([[0.19367318, 0.90507229, 0.12551736, 0.31359607],
#        [0.00504487, 0.47155694, 0.08476019, 0.00172445],
#        [0.06612725, 0.64043058, 0.24928998, 0.70603084],
#        ...,
#        [0.35512846, 0.7930171 , 0.81653665, 0.71009262],
#        [0.42955994, 0.86509021, 0.90355361, 0.65579711],
#        [0.21560364, 0.16380368, 0.80373505, 0.34367508]])

# %%
l = newdf.T
l.T
# Out:
#             0         1         2         3
# 0    0.193673  0.905072  0.125517  0.313596
# 1    0.005045  0.471557  0.084760  0.001724
# 2    0.066127  0.640431  0.249290  0.706031
# 3    0.911217  0.294054  0.016739  0.998522
# 4    0.797130  0.690922  0.868651  0.518091
# ..        ...       ...       ...       ...
# 435  0.856059  0.770301  0.002219  0.095408
# 436  0.320456  0.396511  0.515311  0.406790
# 437  0.355128  0.793017  0.816537  0.710093
# 438  0.429560  0.865090  0.903554  0.655797
# 439  0.215604  0.163804  0.803735  0.343675
#
# [440 rows x 4 columns]

# %%
newdf.sort_index(axis=1,ascending=False)
newdf.head()
# Out:
#           0         1         2         3
# 0  0.193673  0.905072  0.125517  0.313596
# 1  0.005045  0.471557  0.084760  0.001724
# 2  0.066127  0.640431  0.249290  0.706031
# 3  0.911217  0.294054  0.016739  0.998522
# 4  0.797130  0.690922  0.868651  0.518091

# %%
type(newdf[0])
newdf2 = newdf
newdf2[0][0] = 4829

# %%
newdf2
# Out:
#                0         1         2         3
# 0    4829.000000  0.905072  0.125517  0.313596
# 1       0.005045  0.471557  0.084760  0.001724
# 2       0.066127  0.640431  0.249290  0.706031
# 3       0.911217  0.294054  0.016739  0.998522
# 4       0.797130  0.690922  0.868651  0.518091
# ..           ...       ...       ...       ...
# 435     0.856059  0.770301  0.002219  0.095408
# 436     0.320456  0.396511  0.515311  0.406790
# 437     0.355128  0.793017  0.816537  0.710093
# 438     0.429560  0.865090  0.903554  0.655797
# 439     0.215604  0.163804  0.803735  0.343675
#
# [440 rows x 4 columns]

# %%
newdf3 = newdf.copy() #copy 
newdf3[0][0] = 424122225
print("-------------------------")
newdf
# Out:
# -------------------------
#                0         1         2         3
# 0    4829.000000  0.905072  0.125517  0.313596
# 1       0.005045  0.471557  0.084760  0.001724
# 2       0.066127  0.640431  0.249290  0.706031
# 3       0.911217  0.294054  0.016739  0.998522
# 4       0.797130  0.690922  0.868651  0.518091
# ..           ...       ...       ...       ...
# 435     0.856059  0.770301  0.002219  0.095408
# 436     0.320456  0.396511  0.515311  0.406790
# 437     0.355128  0.793017  0.816537  0.710093
# 438     0.429560  0.865090  0.903554  0.655797
# 439     0.215604  0.163804  0.803735  0.343675
#
# [440 rows x 4 columns]

# %%
newdf.loc[0,1] = 6969

# %%
newdf.head(3)
# Out:
#              0            1         2         3
# 0  4829.000000  6969.000000  0.125517  0.313596
# 1     0.005045     0.471557  0.084760  0.001724
# 2     0.066127     0.640431  0.249290  0.706031

# %%
newdf.columns = list("ABCD")

# %%
newdf.index = list(np.arange(440))

# %%
newdf
# Out:
#                A            B         C         D
# 0    4829.000000  6969.000000  0.125517  0.313596
# 1       0.005045     0.471557  0.084760  0.001724
# 2       0.066127     0.640431  0.249290  0.706031
# 3       0.911217     0.294054  0.016739  0.998522
# 4       0.797130     0.690922  0.868651  0.518091
# ..           ...          ...       ...       ...
# 435     0.856059     0.770301  0.002219  0.095408
# 436     0.320456     0.396511  0.515311  0.406790
# 437     0.355128     0.793017  0.816537  0.710093
# 438     0.429560     0.865090  0.903554  0.655797
# 439     0.215604     0.163804  0.803735  0.343675
#
# [440 rows x 4 columns]

# %%
newdf.loc[[6,7],['A','C']] #use : for all details in given column and row
# Out:
#           A         C
# 6  0.512860  0.086918
# 7  0.044101  0.680460

# %%
newdf.loc[(newdf['B']<0.3) & (newdf['A']>0.5)]
# Out:
#             A         B         C         D
# 3    0.911217  0.294054  0.016739  0.998522
# 5    0.943599  0.273909  0.383969  0.852607
# 11   0.764278  0.279594  0.740195  0.371274
# 17   0.916490  0.268166  0.667313  0.584325
# 24   0.606538  0.296762  0.638480  0.355375
# ..        ...       ...       ...       ...
# 407  0.720184  0.174506  0.586094  0.490561
# 411  0.982707  0.256425  0.659550  0.996711
# 416  0.576093  0.220750  0.248136  0.559774
# 424  0.905786  0.081184  0.847994  0.916229
# 425  0.862981  0.008118  0.902503  0.096338
#
# [69 rows x 4 columns]
