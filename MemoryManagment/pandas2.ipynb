# %%
import pandas as pd
df = pd.DataFrame({
    "Name":["Mitesh D Bediya","Viral Serasiya","Ankit Dasadiya"],
    "Std":[10,11,12],
    "Age":[18,19,20]
})
df1 = pd.Series([22,25,28],name="Age")
df.to_csv("Hello.csv",index=False)
df1
# Out:
# 0    22
# 1    25
# 2    28
# Name: Age, dtype: int64

# %%
df
# Out:
#               Name  Std  Age
# 0  Mitesh D Bediya   10   18
# 1   Viral Serasiya   11   19
# 2   Ankit Dasadiya   12   20

# %%
x = df['Age']
x
# Out:
# 0    18
# 1    19
# 2    20
# Name: Age, dtype: int64

# %%
df['Std'].max()
# Out:
# 12

# %%
df.describe()
# Out:
#         Std   Age
# count   3.0   3.0
# mean   11.0  19.0
# std     1.0   1.0
# min    10.0  18.0
# 25%    10.5  18.5
# 50%    11.0  19.0
# 75%    11.5  19.5
# max    12.0  20.0

# %%
df1.describe()
# Out:
# count     3.0
# mean     25.0
# std       3.0
# min      22.0
# 25%      23.5
# 50%      25.0
# 75%      26.5
# max      28.0
# Name: Age, dtype: float64

# %%
newdf = pd.read_excel("demo.xlsx")

# %%
newdf.info()
print('\n')
print("=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=")
print("=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=")
print("=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=")
print("=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=")
print("=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=")
print("=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=")
print('\n')
newdf
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   0           50 non-null     int64
#  1   First Name  50 non-null     object
#  2   Last Name   50 non-null     object
#  3   Gender      50 non-null     object
#  4   Country     50 non-null     object
#  5   Age         50 non-null     int64
#  6   Date        50 non-null     object
#  7   Id          50 non-null     int64
# dtypes: int64(3), object(5)
# memory usage: 3.2+ KB
#
#
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# ...

# %%
newdf.head(4)
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549

# %%
newdf.loc[0,0] = "Index"

# %%
newdf.loc[0,0] = 1

# %%
newdf[["First Name","Last Name","Gender"]].shape
b = newdf[(newdf['Gender'] == "Male") & (newdf['Age']>30) & (newdf['Country'] == 'United States')]

# %%
b
# Out:
#      0 First Name Last Name Gender        Country  Age        Date    Id
# 28  29      Garth     Gangi   Male  United States   41  16/08/2016  3256
# 34  35     Dewitt    Borger   Male  United States   36  21/05/2015  8514
# 39  40      Chase    Karner   Male  United States   37  15/10/2017  2154
# 48  49     Jeromy      Danz   Male  United States   39  15/10/2017  3265

# %%
p = newdf[(newdf['Gender'] == "Male") & (newdf['Age'] > 30)]
p
# Out:
#      0 First Name Last Name Gender        Country  Age        Date    Id
# 2    3     Philip      Gent   Male         France   36  21/05/2015  2587
# 11  12   Franklyn    Unknow   Male         France   38  15/10/2017  2579
# 28  29      Garth     Gangi   Male  United States   41  16/08/2016  3256
# 34  35     Dewitt    Borger   Male  United States   36  21/05/2015  8514
# 39  40      Chase    Karner   Male  United States   37  15/10/2017  2154
# 48  49     Jeromy      Danz   Male  United States   39  15/10/2017  3265

# %%
weather = pd.read_csv("weather.csv",parse_dates=["Rainfall"])
type(weather.Rainfall[0])
weather
# Out:
#      MinTemp  MaxTemp Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3        0          3.4       6.3          NW
# 1       14.0     26.9      3.6          4.4       9.7         ENE
# 2       13.7     23.4      3.6          5.8       3.3          NW
# 3       13.3     15.5     39.8          7.2       9.1          NW
# 4        7.6     16.1      2.8          5.6      10.6         SSE
# ..       ...      ...      ...          ...       ...         ...
# 361      9.0     30.7        0          7.6      12.1         NNW
# 362      7.1     28.4        0         11.6      12.7           N
# 363     12.5     19.9        0          8.4       5.3         ESE
# 364     12.5     26.9        0          5.0       7.1          NW
# 365     12.3     30.2        0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
weather.set_index('MaxTemp',inplace=True)

# %%
weather
# Out:
#          Evaporation  Sunshine WindGustDir  WindGustSpeed WindDir9am  \
# MaxTemp
# 24.3             3.4       6.3          NW           30.0         SW
# 26.9             4.4       9.7         ENE           39.0          E
# 23.4             5.8       3.3          NW           85.0          N
# 15.5             7.2       9.1          NW           54.0        WNW
# 16.1             5.6      10.6         SSE           50.0        SSE
# ...              ...       ...         ...            ...        ...
# 30.7             7.6      12.1         NNW           76.0        SSE
# 28.4            11.6      12.7           N           48.0        NNW
# 19.9             8.4       5.3         ESE           43.0        ENE
# 26.9             5.0       7.1          NW           46.0        SSW
# 30.2             6.0      12.6          NW           78.0         NW
#
#         WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# MaxTemp
# ...
